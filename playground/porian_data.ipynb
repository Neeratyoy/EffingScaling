# %%
import pandas as pd
porian_df = pd.read_pickle(
    "../data/porian_experiments_results.pickle.xz",
    compression='xz'
)

# %%
porian_df.head()
# Out:
#   dataset hparams warmup   decay   width  depth  \
# 0      rw    base  short  kaplan  1312.0   26.0
# 1      rw    base  short  kaplan   832.0   21.0
# 2      rw    base  short  kaplan  1024.0   23.0
# 3      rw    base  short  kaplan   704.0   18.0
# 4      rw    base   long  kaplan  1504.0   30.0
#
#                                             val/loss  \
# 0  step
# 26       8.273299
# 52       7.264460
# 104  ...
# 1  step
# 36       7.209037
# 72       6.616290
# 144  ...
# 2  step
# 46       7.214812
# 92       6.445248
# 184  ...
# 3  step
# 54       6.982597
# 107      6.311456
# 214  ...
# 4  step
# 18      8.982249
# 36      8.261229
# 71     ...
#
#                                         val/loss_std  \
# 0  step
# 26       0.001030
# 52       0.001519
# 104  ...
# 1  step
# 36       0.001431
# 72       0.001538
# 144  ...
# 2  step
# 46       0.001484
# 92       0.001583
# 184  ...
# 3  step
# 54       0.001568
# 107      0.001525
# 214  ...
# 4  step
# ...
